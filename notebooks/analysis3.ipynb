# %% [markdown]
# # Jason Ramos

# %% [markdown]
# ### Research question/interests:
#
# The dataset is interesting to me because I am currently working a part-time job along with full-time university studies. Apart from generally understanding employee attrition and the potential contributing factors, I am extremely interested in the applications of this data as well. What are the most influencial factors for employee attrition? Of the significant factors, how many are positive and negative? Are there more indicators suggesting that employees **should do** or **shouldn't do** certain things? Furthermore, having a few relatives with businesses of their own, how can this be used by not only employees but also employers? Of the factors that the employers can control, are there any that are significantly impactful? If so, how many and by how much?

# %% [markdown]
# ## **Importing Data**
# ---

# %% [markdown]
# ## **Analysis Pipeline**

# %% [markdown]
# #### Load Data
# - File Type is CSV
# - Delimiter is a comma ( , )
# - All Columns are Non-Null (Gathered from EDA)
#
# #### Clean Data
# No need to drop columns or convert any NaN/Null/None Values
#
# #### Process Data
# - Replace string data to numerical data if applicable
# - Remove Outliers
#
# Many of the string data has already been converted to numerical data. To identify a few:
# 1. Education
# 1. EnvironmentSatisfaction
# 1. JobInvolvement
# 1. JobSatisfaction
# 1. PerformanceRating
# 1. RelationshipSatisfaction
# 1. WorkLifeBalance
#
# #### Wrangle Data
# - No need to restructure data format
# - Dataset comes as one table and does not require further merging

# %%
from project_functions3 import *
df = load_and_process("../data/raw/HR-Employee-Attrition.csv")

# %% [markdown]
# ## **EDA**

# %%
eda(df)
# Out:
# Dataframe Basic Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   category
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   category
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   category
#  7   EducationField            1470 non-null   category
#  8   EnvironmentSatisfaction   1470 non-null   category
#  9   Gender                    1470 non-null   category
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   category
#  12  JobLevel                  1470 non-null   category
# ...
